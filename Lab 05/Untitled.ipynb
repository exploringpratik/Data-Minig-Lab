# %%
from matplotlib import pylab
import pylab as plt
import matplotlib.pyplot as plt

# %%
x = np.linspace(start = 0, stop = 1, num = 1000)
def pdf(sigma, mean,x):
    return np.exp(-np.square((x-mean))/(2*sigma*sigma))/sigma*np.sqrt(2*3.14)
plt.fill(x,pdf(0.1,0.4,x))
plt.fill(x,pdf(0.1,0.6,x))
